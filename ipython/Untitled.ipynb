# %%
import pandas as pd;
import json;
import matplotlib.pyplot as plt;
from sqlalchemy import create_engine;

# %%
con = create_engine('mysql://root:111111@127.0.0.1/stock?charset=utf8')

# %%
df = pd.read_sql('select * from profile_data where name="贵州茅台" and quarter=4', con);

# %%
new_df = df.set_index('year')

plt.gcf().add_subplot(2,2,1)
new_df.gross_profit_rate.plot()

plt.gcf().add_subplot(2,2,2)
new_df.net_profit_ratio.plot()
